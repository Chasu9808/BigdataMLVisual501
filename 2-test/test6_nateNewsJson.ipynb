# %%
# 주의사항, 문자열 안에 특수문자 부분 체크 잘하기.
# create table newsTable (
# id int not null auto_increment,
# title varchar(200),
# publisher varchar(200),
# newsDate varchar(10),
# newsTime varchar(10),
# newsDetail varchar(200),
# newsImgUrl varchar(200),
# primary key(id)
# );
# regex 이용해서, re.sub(매개변수1,매개변수2,매개변수3)
# 매개변수1 : 특정 조건
# 매개변수2 : 대체할 문자
# 매개변수3 : regex를 적용할 문장.

# %%
import time
import bs4
import urllib.request
# import pymysql
import re
import json
def clean_text(inputString):
    text_rmv = re.sub(
        '[-=+,#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·]', ' ', inputString)
    return text_rmv

# 전역변수, 기사에서 가지고 올 정보만 선택한 변수.
imgLinkUrl, subject, link, press, pDate, pTime = "", "", "", "", "", ""

page = 1
count = 1
nateUrl = "https://news.nate.com/recent?cate=its&mid=n0105&type=c&date=20240809&page=1"
# https://news.nate.com/recent?cate=its&mid=n0105&type=c&date=20240719&page=2

htmlObject = urllib.request.urlopen(nateUrl)
webPage = htmlObject.read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

#각 기사 딕션너리 객체, 
# 각 기사를 리스트에 담기. 
news_list = []

while True:
  if (count != 1001):
    try:
        # newsUrl = nateUrl + str(page)
        # newsUrl = nateUrl
        # page += 1
        tag_list = bsObject.findAll('div', {'class': 'mlt01'})
        print('###### 실시간 뉴스 속보 #######')
        for tag in tag_list:
          if (count != 1001):
              
            # strong -> h2 변경 231210 (확인 날짜)
            subject = tag.find('h2', {'class': 'tit'}).text
            subject = clean_text(subject)
            link = tag.find('a', {'class': 'lt1'})['href']
            link = 'https:' + link
            imgLink = tag.find('em', {'class': 'mediatype'})
            # 이미지 없는 경우 처리 부분. 파이썬 null 대신  None
            if imgLink != None:
                imgLinkUrl = imgLink.find('img')['src']
                imgLinkUrl = 'https:' + imgLinkUrl
            else:
                imgLinkUrl = '이미지가 존재 하지 않음'
            pressAndDate = tag.find('span', {'class': 'medium'}).text
            pressAndDate.replace('\t', ' ')
            pressAndDate.replace('\n', '')
            if len(pressAndDate.split()) == 3:
                press, pDate, pTime = pressAndDate.split()
            elif len(pressAndDate.split()) == 4:
                press1, press2, pDate, pTime = pressAndDate.split()
                press = press1+press2
            else:
                pTime = 'pTime없음'
                pDate = 'pDate없음'
                press = 'press없음'
                # continue
            print("순서1: 데이터 추가 전")
            print("subject: %s" % (subject))
            print("press: %s" % (press))
            print("pDate: %s" % (pDate))
            print("pTime: %s" % (pTime))
            print("link: %s" % (link))
            print("imgLinkUrl: %s" % (imgLinkUrl))
            print("count : %d" % count)
            print('================================')
            print('================================')
            word_count = dict()
            word_count['subject'] = subject
            news_list.append(word_count)
            # insertData(subject, press, pDate, pTime, link, imgLinkUrl)
            
            count += 1
            # print('(' , page, ')', subject)
            # print('\t https:'+link, press, pDate, pTime)
            # print('\t imgLink : '+ imgLinkUrl)
          else:
            break
        
        time.sleep(1)
        print(f"count : {count}, page : {page}")
        # print(f"완료!")
        
    except:
        break
  else:
     print(f"완료!")
     # JSON 파일로 저장
     with open('sampleNateNews.json', 'w', encoding='utf-8') as json_file:
        json.dump(news_list, json_file, ensure_ascii=False, indent=4)
     # print(news_list)
     break
    # else:
    #     break
    # 특정 시간마다 동작 여부
    # time.sleep(60)
# Out:
# ###### 실시간 뉴스 속보 #######
# 순서1: 데이터 추가 전
# subject:  콘텐츠 핫&뉴   오디션  한정판 여름 액세서리 획득 이벤트
# press: 매일경제
# pDate: 08-09
# pTime: 12:11
# link: https://news.nate.com/view/20240809n15656?mid=n0105
# imgLinkUrl: https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/mk/2024/08/09/news-p.v1.20240809.3e3bdc54504a4d7ba82eb7e3b124f283_P1.png
# count : 1
# ================================
# ================================
# 순서1: 데이터 추가 전
# subject:  레드벨벳 아이린이 반미 反美 에 꽂혔다고   해외팬들 오역에 웃음폭발
# press: 아시아경제
# pDate: 08-09
# pTime: 11:59
# link: https://news.nate.com/view/20240809n13448?mid=n0105
# imgLinkUrl: https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ae/2024/08/09/ae_1723172345547_295826_0.jpg
# count : 2
# ================================
# ================================
# 순서1: 데이터 추가 전
# subject: 네이버 2분기 역대 최대 실적    라인야후 지분 축소 검토 안해
# press: 경향신문
# pDate: 08-09
# pTime: 11:58
# link: https://news.nate.com/view/20240809n14888?mid=n0105
# imgLinkUrl: https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/kh/2024/08/09/news-p.v1.20240513.95a0be10a24a46349c0d0b75470b22d7_P1.jpeg
# count : 3
# ================================
# ================================
# 순서1: 데이터 추가 전
# subject: 유튜브 인스타 공세에도  앱 화면 바꿨더니 1030 몰려  네이버의  반전
# press: 한국경제
# pDate: 08-09
# pTime: 11:58
# link: https://news.nate.com/view/20240809n15278?mid=n0105
# imgLinkUrl: https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/hk/2024/08/09/01.37060791.1.jpg
# count : 4
# ================================
# ================================
# 순서1: 데이터 추가 전
# subject: 2분기 호실적에 웃은  네카오  AI 등 성장동력 확보는 과제
# press: 연합뉴스
# pDate: 08-09
# pTime: 11:53
# link: https://news.nate.com/view/20240809n15128?mid=n0105
# imgLinkUrl: https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/yt/2024/08/09/AKR20240809065600017_02_i.jpg
# count : 5
# ================================
# ================================
# 순서1: 데이터 추가 전
# subject: 게임물관리위 신임위원에 서태건 정의준
# press: 문화일보
# pDate: 08-09
# pTime: 11:52
# link: https://news.nate.com/view/20240809n15119?mid=n0105
# imgLinkUrl: https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/mh/2024/08/09/2024080901072836000001_b.jpg
# count : 6
# ================================
# ================================
# 순서1: 데이터 추가 전
# subject:  컨콜종합  컴투스  내 외부 신작 가리지 않고 라인업 두텁게 확보
# press: 아이뉴스24
# pDate: 08-09
# pTime: 11:52
# link: https://news.nate.com/view/20240809n15073?mid=n0105
# imgLinkUrl: https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/in/2024/08/09/6b9fa3d1f057ce.jpg
# count : 7
# ================================
# ================================
# 순서1: 데이터 추가 전
# subject: 야당  유상임 후보 아들 마리화나 흡입 드러나  사퇴 요구
# press: 아시아경제
# pDate: 08-09
# pTime: 11:52
# link: https://news.nate.com/view/20240809n15067?mid=n0105
# imgLinkUrl: https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ae/2024/08/09/ae_1723171925330_541625_0.jpg
# count : 8
# ================================
# ================================
# 순서1: 데이터 추가 전
# subject: 일산병원  약제급여 적정성평가  1등급  획득
# press: 파이낸셜뉴스
# pDate: 08-09
# pTime: 11:48
# link: https://news.nate.com/view/20240809n14849?mid=n0105
# imgLinkUrl: https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/fn/2024/08/09/202407301016215202_l.jpg
# count : 9
# ================================
# ================================
# count : 10, page : 1
# 완료!
# [{'subject': ' 콘텐츠 핫&뉴   오디션  한정판 여름 액세서리 획득 이벤트'}, {'subject': ' 레드벨벳 아이린이 반미 反美 에 꽂혔다고   해외팬들 오역에 웃음폭발'}, {'subject': '네이버 2분기 역대 최대 실적    라인야후 지분 축소 검토 안해 '}, {'subject': '유튜브 인스타 공세에도  앱 화면 바꿨더니 1030 몰려  네이버의  반전 '}, {'subject': '2분기 호실적에 웃은  네카오  AI 등 성장동력 확보는 과제'}, {'subject': '게임물관리위 신임위원에 서태건 정의준'}, {'subject': ' 컨콜종합  컴투스  내 외부 신작 가리지 않고 라인업 두텁게 확보 '}, {'subject': '야당  유상임 후보 아들 마리화나 흡입 드러나  사퇴 요구'}, {'subject': '일산병원  약제급여 적정성평가  1등급  획득'}]
